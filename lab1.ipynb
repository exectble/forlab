# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
imgplane = Image.open('plane.png') 
arrimg = np.array(imgplane)

K=[]
for i in range(len(arrimg)):
    Ki=[]
    for j in range(len(arrimg[i])):
        Ki.append(int(arrimg[i][j][0]* 0.299 + arrimg[i][j][1]* 0.587 + arrimg[i][j][2]* 0.114))
    K.append(Ki)
    
plt.imshow(K, cmap='binary_r')
plt.show()

# %%
k=[]
for i in K:
    for j in i:
        k.append(j)

# %%
fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot()
ax.hist(k, bins=20)
ax.grid()
 
plt.show()

# %%
for i in range(len(arrimg)):
    for j in range(len(arrimg[i])):
        ki = K[i][j]
        if ki >= 0 and ki < 90:
            arrimg[i][j][0] = 255
            arrimg[i][j][1] = 0
            arrimg[i][j][2] = 0
plt.imshow(arrimg)

# %%
Image.fromarray(arrimg).save('redplane.png')
